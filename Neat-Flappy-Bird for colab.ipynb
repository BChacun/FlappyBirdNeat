# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ntasfi/PyGame-Learning-Environment
# Out:
# Cloning into 'PyGame-Learning-Environment'...
# remote: Enumerating objects: 1118, done.
# remote: Total 1118 (delta 0), reused 0 (delta 0), pack-reused 1118
# Receiving objects: 100% (1118/1118), 8.06 MiB | 17.85 MiB/s, done.
# Resolving deltas: 100% (592/592), done.

# %%
import gym
from gym import spaces
import numpy as np
from ple import PLE
from ple.games.flappybird import FlappyBird

class FlappyBirdEnv(gym.Env):
    def __init__(self):
        self.game = FlappyBird()
        self.p = PLE(self.game, fps=30, display_screen=True)
        self.p.init()
        self.action_set = self.p.getActionSet()

        # Define observation space using the keys from getGameState
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(8,), dtype=np.float32)
        self.action_space = spaces.Discrete(len(self.action_set))

    def reset(self):
        self.p.reset_game()
        return self.get_observation()

    def step(self, action):
        # Ensure action is within valid range
        if action >= len(self.action_set):
            action = 0
        reward = self.p.act(self.action_set[action])
        state = self.get_observation()
        done = self.p.game_over()
        return state, reward, done, {}

    def get_observation(self):
        state = self.p.getGameState()
        return np.array(list(state.values()), dtype=np.float32)

    def render(self, mode='rgb_array'):
        if mode == 'rgb_array':
            return self.p.getScreenRGB()
        elif mode == 'human':
            self.p.display_screen = True
        else:
            super(FlappyBirdEnv, self).render(mode=mode)

    def close(self):
        self.p.close()

# Register the custom environment
gym.envs.registration.register(id='FlappyBird-v0', entry_point=FlappyBirdEnv)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:542: UserWarning: WARN: Overriding environment FlappyBird-v0
#   logger.warn(f"Overriding environment {spec.id}")

# %%
import os
import neat
import pickle
import numpy as np
import gym

# Define the evaluation function for the NEAT algorithm
def eval_genomes(genomes, config):
    env = gym.make('FlappyBird-v0')
    for genome_id, genome in genomes:
        observation = env.reset()
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        genome.fitness = 0
        done = False
        while not done:
            action = np.argmax(net.activate(observation))
            observation, reward, done, info = env.step(action)
            genome.fitness += reward
    env.reset()

# Set up the NEAT configuration
def run_neat(config_file):
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction, neat.DefaultSpeciesSet, neat.DefaultStagnation, config_file)
    p = neat.Population(config)
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    winner = p.run(eval_genomes, 50)

    with open('winner.pkl', 'wb') as f:
        pickle.dump(winner, f)

    return winner

# Load the NEAT configuration and run the algorithm
config_path = 'config-feedforward.txt'
winner = run_neat(config_path)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (3, 0) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.098, standard deviation 0.289
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50     -5.0    0.000     0
# Total extinctions: 0
# Generation time: 6.331 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (3, 0) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.326, standard deviation 0.291
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50     -5.0    0.000     1
# Total extinctions: 0
# Generation time: 5.026 sec (5.678 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -5.00000 stdev: 0.00000
# Best fitness: -5.00000 - size: (3, 0) - species 1 - id 1
# Average adjusted fitness: 0.000
# Mean genetic distance 1.430, standard deviation 0.333
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50     -5.0    0.000     2
# Total extinctions: 0
# Generation time: 4.713 sec (5.357 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -4.92000 stdev: 0.33705
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.040
# Mean genetic distance 1.503, standard deviation 0.350
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50     -3.0    0.040     0
# Total extinctions: 0
# Generation time: 6.149 sec (5.555 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -4.94000 stdev: 0.31048
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.030
# Mean genetic distance 1.594, standard deviation 0.299
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50     -3.0    0.030     1
# Total extinctions: 0
# Generation time: 4.898 sec (5.424 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -4.90000 stdev: 0.36056
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.050
# Mean genetic distance 1.705, standard deviation 0.330
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    50     -3.0    0.050     2
# Total extinctions: 0
# Generation time: 5.224 sec (5.390 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -4.94000 stdev: 0.31048
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.030
# Mean genetic distance 1.822, standard deviation 0.380
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    50     -3.0    0.030     3
# Total extinctions: 0
# Generation time: 4.793 sec (5.305 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -4.88000 stdev: 0.38158
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.060
# Mean genetic distance 1.778, standard deviation 0.436
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    50     -3.0    0.060     4
# Total extinctions: 0
# Generation time: 4.631 sec (5.221 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -4.90000 stdev: 0.36056
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.050
# Mean genetic distance 1.934, standard deviation 0.365
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    50     -3.0    0.050     5
# Total extinctions: 0
# Generation time: 4.891 sec (5.184 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -4.94000 stdev: 0.31048
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.030
# Mean genetic distance 1.969, standard deviation 0.328
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    50     -3.0    0.030     6
# Total extinctions: 0
# Generation time: 5.540 sec (5.220 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -4.96000 stdev: 0.28000
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.020
# Mean genetic distance 1.942, standard deviation 0.421
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    50     -3.0    0.020     7
# Total extinctions: 0
# Generation time: 4.348 sec (5.022 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -4.94000 stdev: 0.31048
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.030
# Mean genetic distance 1.942, standard deviation 0.461
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    50     -3.0    0.030     8
# Total extinctions: 0
# Generation time: 3.678 sec (4.887 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -4.92000 stdev: 0.33705
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.040
# Mean genetic distance 1.954, standard deviation 0.303
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    50     -3.0    0.040     9
# Total extinctions: 0
# Generation time: 5.237 sec (4.939 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -4.92000 stdev: 0.33705
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.040
# Mean genetic distance 1.877, standard deviation 0.262
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    50     -3.0    0.040    10
# Total extinctions: 0
# Generation time: 4.193 sec (4.743 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -4.92000 stdev: 0.33705
# Best fitness: -3.00000 - size: (4, 8) - species 1 - id 155
# Average adjusted fitness: 0.040
# Mean genetic distance 1.987, standard deviation 0.367
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    50     -3.0    0.040    11
# Total extinctions: 0
# Generation time: 4.243 sec (4.678 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -4.84000 stdev: 0.64374
# Best fitness: -1.00000 - size: (3, 9) - species 1 - id 742
# Average adjusted fitness: 0.040
# Mean genetic distance 2.114, standard deviation 0.392
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    15     -1.0    0.040     0
#      2    0    35       --       --     0
# Total extinctions: 0
# Generation time: 5.903 sec (4.746 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -4.88000 stdev: 0.58788
# Best fitness: -1.00000 - size: (4, 8) - species 2 - id 155
# Average adjusted fitness: 0.026
# Mean genetic distance 2.079, standard deviation 0.527
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    13     -4.0    0.017     1
#      2    1    37     -1.0    0.036     0
# Total extinctions: 0
# Generation time: 4.407 sec (4.707 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -4.82000 stdev: 0.65391
# Best fitness: -1.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.062
# Mean genetic distance 2.253, standard deviation 0.550
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    27     -1.0    0.096     2
#      2    2    23     -3.0    0.027     1
# Total extinctions: 0
# Generation time: 5.126 sec (4.757 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -4.72000 stdev: 0.98061
# Best fitness: 1.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.046
# Mean genetic distance 2.341, standard deviation 0.531
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    26      1.0    0.049     0
#      2    3    24     -2.0    0.043     2
# Total extinctions: 0
# Generation time: 6.313 sec (4.899 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -4.78000 stdev: 1.00578
# Best fitness: 1.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.037
# Mean genetic distance 2.381, standard deviation 0.458
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    21      1.0    0.038     1
#      2    4    29     -1.0    0.035     3
# Total extinctions: 0
# Generation time: 4.157 sec (4.761 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -4.64000 stdev: 1.17915
# Best fitness: 1.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.058
# Mean genetic distance 2.287, standard deviation 0.443
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    13      1.0    0.048     2
#      2    5    25      0.0    0.069     0
#      3    0    12       --       --     0
# Total extinctions: 0
# Generation time: 5.932 sec (4.919 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -4.60000 stdev: 2.00000
# Best fitness: 9.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.031
# Mean genetic distance 2.258, standard deviation 0.589
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    15      9.0    0.077     0
#      2    6    14     -2.0    0.017     1
#      3    1    21     -5.0    0.000     0
# Total extinctions: 0
# Generation time: 6.420 sec (5.193 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -4.82000 stdev: 0.88747
# Best fitness: 1.00000 - size: (3, 11) - species 3 - id 821
# Average adjusted fitness: 0.026
# Mean genetic distance 2.180, standard deviation 0.697
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     9     -5.0    0.000     1
#      2    7    12     -3.0    0.024     2
#      3    2    29      1.0    0.056     0
# Total extinctions: 0
# Generation time: 4.809 sec (5.150 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -4.68000 stdev: 1.15655
# Best fitness: 2.00000 - size: (4, 12) - species 3 - id 838
# Average adjusted fitness: 0.026
# Mean genetic distance 2.081, standard deviation 0.550
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     5     -5.0    0.000     2
#      2    8     3     -5.0    0.000     3
#      3    3    42      2.0    0.079     0
# Total extinctions: 0
# Generation time: 6.693 sec (5.400 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -4.44000 stdev: 2.85068
# Best fitness: 15.00000 - size: (3, 11) - species 3 - id 821
# Average adjusted fitness: 0.011
# Mean genetic distance 2.091, standard deviation 0.599
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     4     -5.0    0.000     3
#      2    9     6     -5.0    0.000     4
#      3    4    40     15.0    0.033     0
# Total extinctions: 0
# Generation time: 5.889 sec (5.565 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -3.02000 stdev: 13.15825
# Best fitness: 89.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.084
# Mean genetic distance 2.177, standard deviation 0.688
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    20     89.0    0.250     0
#      2   10     5     -4.0    0.002     5
#      3    5    25     -1.0    0.001     1
# Total extinctions: 0
# Generation time: 12.136 sec (6.188 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -4.58000 stdev: 1.63817
# Best fitness: 6.00000 - size: (3, 11) - species 1 - id 821
# Average adjusted fitness: 0.039
# Mean genetic distance 2.246, standard deviation 0.536
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    12      6.0    0.059     1
#      2   11    18     -4.0    0.036     6
#      3    6    20     -1.0    0.022     2
# Total extinctions: 0
# Generation time: 5.709 sec (6.318 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -4.62000 stdev: 1.41266
# Best fitness: 3.00000 - size: (4, 12) - species 3 - id 838
# Average adjusted fitness: 0.042
# Mean genetic distance 2.130, standard deviation 0.572
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27     9     -5.0    0.000     2
#      2   12    28      1.0    0.062     0
#      3    7    14      3.0    0.062     3
# Total extinctions: 0
# Generation time: 6.094 sec (6.415 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -3.92157 stdev: 5.64243
# Best fitness: 35.00000 - size: (3, 11) - species 2 - id 1322
# Average adjusted fitness: 0.018
# Mean genetic distance 2.073, standard deviation 0.634
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28     5     -5.0    0.000     3
#      2   13    36     35.0    0.044     0
#      3    8     9     -1.0    0.011     4
# Total extinctions: 0
# Generation time: 8.224 sec (6.606 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -4.16000 stdev: 3.81764
# Best fitness: 21.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.017
# Mean genetic distance 2.031, standard deviation 0.592
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29     3     -5.0    0.000     4
#      2   14    35     21.0    0.043     1
#      3    9    12     -3.0    0.009     5
# Total extinctions: 0
# Generation time: 8.153 sec (7.006 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -3.62000 stdev: 9.09481
# Best fitness: 60.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.010
# Mean genetic distance 1.953, standard deviation 0.651
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30     2     -5.0    0.000     5
#      2   15    40     60.0    0.030     0
#      3   10     8     -4.0    0.001     6
# Total extinctions: 0
# Generation time: 9.854 sec (7.398 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -2.90000 stdev: 9.78826
# Best fitness: 54.00000 - size: (3, 11) - species 2 - id 1322
# Average adjusted fitness: 0.017
# Mean genetic distance 2.009, standard deviation 0.656
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31     3     -5.0    0.000     6
#      2   16    39     54.0    0.043     1
#      3   11     8     -3.0    0.006     7
# Total extinctions: 0
# Generation time: 10.868 sec (7.843 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -3.76000 stdev: 7.69041
# Best fitness: 50.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.011
# Mean genetic distance 2.016, standard deviation 0.615
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32     2     -5.0    0.000     7
#      2   17    41     50.0    0.028     2
#      3   12     7     -3.0    0.005     8
# Total extinctions: 0
# Generation time: 9.516 sec (8.314 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -2.98000 stdev: 9.80100
# Best fitness: 54.00000 - size: (3, 11) - species 2 - id 1322
# Average adjusted fitness: 0.015
# Mean genetic distance 1.997, standard deviation 0.594
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33     2     -5.0    0.000     8
#      2   18    42     54.0    0.041     3
#      3   13     6     -3.0    0.005     9
# Total extinctions: 0
# Generation time: 12.437 sec (8.888 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -3.66000 stdev: 7.70613
# Best fitness: 50.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.011
# Mean genetic distance 2.040, standard deviation 0.609
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34     2     -5.0    0.000     9
#      2   19    41     50.0    0.028     4
#      3   14     7     -3.0    0.006    10
# Total extinctions: 0
# Generation time: 9.996 sec (9.299 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -2.92000 stdev: 9.79151
# Best fitness: 54.00000 - size: (3, 11) - species 2 - id 1322
# Average adjusted fitness: 0.016
# Mean genetic distance 2.039, standard deviation 0.584
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35     4     -5.0    0.000    10
#      2   20    36     54.0    0.042     5
#      3   15    10     -3.0    0.007    11
# Total extinctions: 0
# Generation time: 11.069 sec (9.192 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -3.52000 stdev: 9.08678
# Best fitness: 60.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.012
# Mean genetic distance 1.943, standard deviation 0.629
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36     4     -5.0    0.000    11
#      2   21    36     60.0    0.030     6
#      3   16    10     -3.0    0.006    12
# Total extinctions: 0
# Generation time: 10.140 sec (9.635 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -4.46000 stdev: 2.77280
# Best fitness: 14.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.014
# Mean genetic distance 1.991, standard deviation 0.569
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37     3     -5.0    0.000    12
#      2   22    37     14.0    0.038     7
#      3   17    10     -4.0    0.005    13
# Total extinctions: 0
# Generation time: 7.456 sec (9.771 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -3.54000 stdev: 9.08672
# Best fitness: 60.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.011
# Mean genetic distance 1.933, standard deviation 0.585
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38     3     -5.0    0.000    13
#      2   23    37     60.0    0.029     8
#      3   18    10     -4.0    0.005    14
# Total extinctions: 0
# Generation time: 9.126 sec (9.862 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -3.74000 stdev: 7.69626
# Best fitness: 50.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.012
# Mean genetic distance 1.959, standard deviation 0.588
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39     2     -5.0    0.000    14
#      2   24    39     50.0    0.029     9
#      3   19     9     -3.0    0.005    15
# Total extinctions: 0
# Generation time: 9.881 sec (10.034 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -3.50000 stdev: 9.09120
# Best fitness: 60.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.012
# Mean genetic distance 1.994, standard deviation 0.522
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40     3     -5.0    0.000    15
#      2   25    34     60.0    0.028    10
#      3   20    13     -2.0    0.009    16
# Total extinctions: 0
# Generation time: 10.540 sec (10.103 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -4.40000 stdev: 2.77128
# Best fitness: 14.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.017
# Mean genetic distance 1.973, standard deviation 0.590
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41     4     -5.0    0.000    16
#      2   26    35     14.0    0.043    11
#      3   21    11     -4.0    0.008    17
# Total extinctions: 0
# Generation time: 6.090 sec (9.625 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: -4.08000 stdev: 3.08441
# Best fitness: 14.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.029
# Mean genetic distance 1.977, standard deviation 0.578
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   42     3     -5.0    0.000    17
#      2   27    35     14.0    0.062    12
#      3   22    12     -2.0    0.024    18
# Total extinctions: 0
# Generation time: 8.956 sec (9.569 average)
#
#  ****** Running generation 43 ******
#
# Population's average fitness: -4.62000 stdev: 1.96865
# Best fitness: 9.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.014
# Mean genetic distance 1.971, standard deviation 0.565
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   43     2     -5.0    0.000    18
#      2   28    39      9.0    0.037    13
#      3   23     9     -4.0    0.006    19
# Total extinctions: 0
# Generation time: 5.590 sec (8.884 average)
#
#  ****** Running generation 44 ******
#
# Population's average fitness: -3.56000 stdev: 9.09541
# Best fitness: 60.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.014
# Mean genetic distance 2.033, standard deviation 0.605
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   44     6     -4.0    0.008    19
#      2   29    32     60.0    0.026    14
#      3   24    12     -2.0    0.009    20
# Total extinctions: 0
# Generation time: 9.926 sec (8.878 average)
#
#  ****** Running generation 45 ******
#
# Population's average fitness: -4.68000 stdev: 0.94742
# Best fitness: 0.00000 - size: (3, 11) - species 2 - id 821
#
# Species 1 with 6 members is stagnated: removing it
# Average adjusted fitness: 0.068
# Mean genetic distance 1.828, standard deviation 0.476
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   30    27      0.0    0.069    15
#      3   25    23     -3.0    0.067    21
# Total extinctions: 0
# Generation time: 5.357 sec (8.306 average)
#
#  ****** Running generation 46 ******
#
# Population's average fitness: -4.66000 stdev: 0.92973
# Best fitness: -1.00000 - size: (3, 11) - species 3 - id 2116
# Average adjusted fitness: 0.085
# Mean genetic distance 1.967, standard deviation 0.475
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   31    28     -1.0    0.083    16
#      3   26    22     -1.0    0.087    22
# Total extinctions: 0
# Generation time: 7.023 sec (7.995 average)
#
#  ****** Running generation 47 ******
#
# Population's average fitness: -4.68000 stdev: 1.39198
# Best fitness: 3.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.036
# Mean genetic distance 1.902, standard deviation 0.569
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   32    37      3.0    0.067    17
#      3   27    13     -4.0    0.006    23
# Total extinctions: 0
# Generation time: 4.857 sec (7.735 average)
#
#  ****** Running generation 48 ******
#
# Population's average fitness: -4.40000 stdev: 3.01330
# Best fitness: 16.00000 - size: (3, 6) - species 2 - id 2226
# Average adjusted fitness: 0.020
# Mean genetic distance 1.952, standard deviation 0.473
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   33    40     16.0    0.037    18
#      3   28    10     -4.0    0.004    24
# Total extinctions: 0
# Generation time: 7.108 sec (7.533 average)
#
#  ****** Running generation 49 ******
#
# Population's average fitness: -3.28000 stdev: 5.73425
# Best fitness: 22.00000 - size: (3, 11) - species 2 - id 821
# Average adjusted fitness: 0.043
# Mean genetic distance 1.898, standard deviation 0.432
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      2   34    38     22.0    0.078    19
#      3   29    12     -4.0    0.007    25
# Total extinctions: 0
# Generation time: 10.092 sec (7.554 average)

# %%
import gym
import moviepy.editor as mpy
import neat
import pickle
import numpy as np

def visualize_winner(winner, config):
    env = gym.make('FlappyBird-v0')
    observation = env.reset()
    net = neat.nn.FeedForwardNetwork.create(winner, config)
    frames = []
    done = False

    while not done:
        frame = env.render()
        if frame is not None:
            frames.append(frame)
        action = np.argmax(net.activate(observation))
        observation, reward, done, _ = env.step(action)

    env.reset()  # Reset the environment instead of closing

    # Ensure there are no None frames in the list
    if len(frames) == 0:
        print("No frames were captured.")
        return

    frames = [frame for frame in frames if frame is not None]

    # Create a video from the frames
    clip = mpy.ImageSequenceClip(frames, fps=30)
    clip.write_videofile('flappy_bird_neat.mp4')

# Load the trained model and visualize
with open('winner.pkl', 'rb') as f:
    winner = pickle.load(f)

config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction, neat.DefaultSpeciesSet, neat.DefaultStagnation, config_path)
visualize_winner(winner, config)
# Out:
# Moviepy - Building video flappy_bird_neat.mp4.
# Moviepy - Writing video flappy_bird_neat.mp4
# Moviepy - Done !
# Moviepy - video ready flappy_bird_neat.mp4
